# %%
import pylab as pl
import itertools
import math
import statistics

# %%
def insertionSortSt(array):
    steps = 0
    compa = 0
    swaps = 0
    
    for i in range(1,len(array)):   
        aux = array[i]
        j = i - 1        
        while j > -1 and aux < array[j]:
            compa += 1
            array[j + 1] = array[j]
            swaps += 1
            steps += 3        
            j = j - 1
                      
        steps += 1
        array[j + 1] = aux
        steps += 4
        
        if j != i:
            compa += 1
    
    steps += 1
    
    arrayComp = [steps,compa,swaps]
    return arrayComp

# %%
def main(n):
    listaPerm=[]
    arrSteps=[]
    arrCompa=[]
    arrSwaps=[]
    medSteps = 0
    medComp = 0
    medSwaps = 0

    #Lista de Permutaciones de un Arreglo de 0 a n.
    for i in range(n):
        listaPerm.append(i)
    permutations = (list(itertools.permutations(listaPerm)))

    #print(permutations)
    print("..............................................................")
    print("Arreglo de Tamaño: {}".format(n))
    print("Número de Permutaciones Posibles: {}".format(len(permutations)))

    #Para cada permutación, ordena y separa el conteo de pasos realizados para cada caso.
    for perm in permutations:
        conteo = insertionSortSt(list(perm))
        #print(conteo)
        arrSteps.append(conteo[0])
        arrCompa.append(conteo[1])
        arrSwaps.append(conteo[2])

    medSteps = statistics.mean(arrSteps)
    medCompa = statistics.mean(arrCompa)
    medSwaps = statistics.mean(arrSwaps)

    #Grafica un histograma para cada caso de Complejidad.
    pl.hist(arrSteps, bins='auto')
    pl.title("Histograma Steps")
    pl.show()
    print("Número Medio de Pasos: {}".format(medSteps))
    
    pl.hist(arrCompa, bins='auto')
    pl.title("Histograma Comparisons")
    pl.show()
    print("Número Medio de Pasos: {}".format(medCompa))

    pl.hist(arrSwaps, bins='auto')
    pl.title("Histograma Swaps")
    pl.show()
    print("Número Medio de Pasos: {}".format(medSwaps))

# %%
main(4)
# Out:
# ..............................................................
# Arreglo de Tamaño: 4
# Número de Permutaciones Posibles: 24
# Número Medio de Pasos: 25
# Número Medio de Pasos: 6
# Número Medio de Pasos: 3

# %%
main(8)
# Out:
# ..............................................................
# Arreglo de Tamaño: 8
# Número de Permutaciones Posibles: 40320
# Número Medio de Pasos: 78
# Número Medio de Pasos: 21
# Número Medio de Pasos: 14

# %%
main(10)
# Out:
# ..............................................................
# Arreglo de Tamaño: 10
# Número de Permutaciones Posibles: 3628800
# Número Medio de Pasos: 113.5
# Número Medio de Pasos: 31.5
# Número Medio de Pasos: 22.5
